# %%
from pyecharts import Bar

attr = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
bar = Bar("Bar chart", "precipitation and evaporation one year")
bar.add("precipitation", attr, v1, mark_line=["average"], mark_point=["max", "min"])
bar.add("evaporation", attr, v2, mark_line=["average"], mark_point=["max", "min"])
bar.render()

# %%
from pyecharts import Pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="438e4dc2eb4446248b995488564d60c2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_438e4dc2eb4446248b995488564d60c2 = echarts.init(document.getElementById('438e4dc2eb4446248b995488564d60c2'), 'light', {renderer: 'canvas'});
#
# var option_438e4dc2eb4446248b995488564d60c2 = {
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "precipitation and evaporation one year",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
bar = Bar('我的第一个图表','这里是副标题')
kwargs = dict(
    name = '柱形图',
    x_axis = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子'],
    y_axis = [5,20,36,10,75,90]
)
bar.add(**kwargs)
bar.render('bar01.html')

# %%
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b98cab82dcdf4d4081f544610dfcf8ec" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b98cab82dcdf4d4081f544610dfcf8ec = echarts.init(document.getElementById('b98cab82dcdf4d4081f544610dfcf8ec'), 'light', {renderer: 'canvas'});
#
# var option_b98cab82dcdf4d4081f544610dfcf8ec = {
#     "title": [
#         {
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
lf = pd.read_json('/Users/user/Desktop/tutorial-from-youtube/logfile.json')
lf.head()
# Out:
#   department  effect  evaluation  heard  importance username
# 0         it       8           5      1           5     bbbb
# 1   business       2           1      0           2     bbbb
# 2         it       1           3      0           2     bbbb
# 3         it       7           1      1           5     bbbb
# 4         it       2           2      1           4     bbbb

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('/Users/user/Desktop/Flask_Blog/flaskblog/static/faurecia.json')
df.head()
# Out:
#          Cycle time Maximum injection pressure  Melt temperature  \
# 0  60,2402157584596           303,183269160703  204,775796004076
# 1  59,7077040565916            316,45258726377  191,124392082044
# 2  59,4457038445446           300,434737228826  193,175360711396
# 3   61,651186181209           294,812475880438  212,447118991426
# 4  59,2462566309729           310,500184033095  218,771155102027
#
#   Mold wall temperature  Packing pressure      Packing time       Part weight  \
# 0      136,232090338703  96,2174429374479  2,03929257688295  300,225785600272
# 1      144,106001162583  102,647633825739  1,93168410379266  283,555978441663
# 2      132,707457243651   108,59073974678  1,92055905662103   287,78807175208
# 3      152,928157498737  100,313796790298   1,9492333715404  300,221216434511
# 4      138,154297922142  96,9363796581796  1,90417361690823  310,570134060327
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# ...

# %%
df.describe()
# Out:
#          Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# count  10000.000000                10000.000000      10000.000000
# mean      60.015300                  299.963200        200.031200
# std        0.934534                    8.595059          8.657847
# min       58.000000                  280.000000        180.000000
# 25%       59.000000                  294.000000        194.000000
# 50%       60.000000                  300.000000        200.000000
# 75%       61.000000                  306.000000        206.000000
# max       62.000000                  320.000000        220.000000
#
#        Mold_wall_temperature  Packing_pressure  Packing_time   Part_weight  \
# count           10000.000000      10000.000000       10000.0  10000.000000
# mean              149.892700        100.033800           2.0    299.759500
# std                 8.485799          8.716379           0.0      9.248168
# ...

# %%
print("Correlation:", df.corr(method='pearson'))
# Out:
# Correlation:                             Cycle_time  Maximum_injection_pressure  \
# Cycle_time                    1.000000                    0.007578
# Maximum_injection_pressure    0.007578                    1.000000
# Melt_temperature              0.004416                    0.017476
# Mold_wall_temperature        -0.000197                    0.005572
# Packing_pressure             -0.018689                   -0.000360
# Packing_time                       NaN                         NaN
# Part_weight                   0.005888                    0.018474
# Quality                      -0.007000                    0.006846
# Sequence                      0.017383                   -0.009554
#
#                             Melt_temperature  Mold_wall_temperature  \
# Cycle_time                          0.004416              -0.000197
# Maximum_injection_pressure          0.017476               0.005572
# Melt_temperature                    1.000000              -0.006027
# ...

# %%
df['Cycle_time'].value_counts()
# Out:
# 60    3992
# 61    2613
# 59    2486
# 62     461
# 58     448
# Name: Cycle_time, dtype: int64

# %%
from pyecharts import Bar
from pyecharts import Pie
from pyecharts import configure
configure(global_theme='walden')

# %%
df['Cycle_time'].between(left=58, right=60).sum()
# Out:
# 6926

# %%
df['Cycle_time']

# %%
df = pd.read_json('/Users/user/Desktop/Flask_Blog/mockup.json')

# %%
df.head()
# Out:
#    Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 0          60                         303               205
# 1          60                         316               191
# 2          59                         300               193
# 3          62                         295               212
# 4          59                         310               219
#
#    Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 0                    136                96             2          300
# 1                    144               103             2          284
# 2                    133               109             2          288
# 3                    153               100             2          300
# 4                    138                97             2          311
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# 3        1         4
# 4        1         5

# %%
df.columns = ['Cycle_time', 'Maximum_injection_pressure','Melt_temperature', 'Mold_wall_temperature', 'Packing_pressure', 'Packing_time','Part_weight','Quality','Sequence']

# %%
df.info
# Out:
# <bound method DataFrame.info of             Cycle_time Maximum_injection_pressure  Melt_temperature  \
# 0     60,2402157584596           303,183269160703  204,775796004076
# 1     59,7077040565916            316,45258726377  191,124392082044
# 2     59,4457038445446           300,434737228826  193,175360711396
# 3      61,651186181209           294,812475880438  212,447118991426
# 4     59,2462566309729           310,500184033095  218,771155102027
# 5     59,4642641140136           300,120745326138  182,553725909692
# 6     60,4430859318736           302,284041683497   212,34047895371
# 7     58,1210721407364           308,851715446721    210,8922578067
# 8     60,9316404743656           297,045126681715  200,655211098141
# 9     59,4961867078728           304,835349636465  206,402828062524
# 10    61,1619440814908           308,815584522919  196,071022137872
# 11    59,3224648520144           291,172107310038  206,649205347868
# ...

# %%
df.head()
# Out:
#          Cycle_time Maximum_injection_pressure  Melt_temperature  \
# 0  60,2402157584596           303,183269160703  204,775796004076
# 1  59,7077040565916            316,45258726377  191,124392082044
# 2  59,4457038445446           300,434737228826  193,175360711396
# 3   61,651186181209           294,812475880438  212,447118991426
# 4  59,2462566309729           310,500184033095  218,771155102027
#
#   Mold_wall_temperature  Packing_pressure      Packing_time       Part_weight  \
# 0      136,232090338703  96,2174429374479  2,03929257688295  300,225785600272
# 1      144,106001162583  102,647633825739  1,93168410379266  283,555978441663
# 2      132,707457243651   108,59073974678  1,92055905662103   287,78807175208
# 3      152,928157498737  100,313796790298   1,9492333715404  300,221216434511
# 4      138,154297922142  96,9363796581796  1,90417361690823  310,570134060327
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# ...

# %%
df['Maximum_injection_pressure'] = df['Maximum_injection_pressure'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Melt_temperature'] = df['Melt_temperature'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Mold_wall_temperature'] = df['Mold_wall_temperature'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Packing_pressure'] = df['Packing_pressure'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Packing_time'] = df['Packing_time'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Part_weight'] = df['Part_weight'].map(lambda x:x.replace(',', '.') if ',' in x else x)
df['Cycle_time'] = df['Cycle_time'].map(lambda x:x.replace(',', '.') if ',' in x else x)

# %%
df.head()
# Out:
#          Cycle_time Maximum_injection_pressure  Melt_temperature  \
# 0  60.2402157584596           303.183269160703  204.775796004076
# 1  59.7077040565916            316.45258726377  191.124392082044
# 2  59.4457038445446           300.434737228826  193.175360711396
# 3   61.651186181209           294.812475880438  212.447118991426
# 4  59.2462566309729           310.500184033095  218.771155102027
#
#   Mold_wall_temperature  Packing_pressure      Packing_time       Part_weight  \
# 0      136.232090338703  96.2174429374479  2.03929257688295  300.225785600272
# 1      144.106001162583  102.647633825739  1.93168410379266  283.555978441663
# 2      132.707457243651   108.59073974678  1.92055905662103   287.78807175208
# 3      152.928157498737  100.313796790298   1.9492333715404  300.221216434511
# 4      138.154297922142  96.9363796581796  1.90417361690823  310.570134060327
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# ...

# %%
df = df.to_csv('/Users/user/Desktop/Flask_Blog/aaa.csv')

# %%
df = df.round(0)

# %%
df.head()
# Out:
#          Cycle_time Maximum_injection_pressure  Melt_temperature  \
# 0  60.2402157584596           303.183269160703  204.775796004076
# 1  59.7077040565916            316.45258726377  191.124392082044
# 2  59.4457038445446           300.434737228826  193.175360711396
# 3   61.651186181209           294.812475880438  212.447118991426
# 4  59.2462566309729           310.500184033095  218.771155102027
#
#   Mold_wall_temperature  Packing_pressure      Packing_time       Part_weight  \
# 0      136.232090338703  96.2174429374479  2.03929257688295  300.225785600272
# 1      144.106001162583  102.647633825739  1.93168410379266  283.555978441663
# 2      132.707457243651   108.59073974678  1.92055905662103   287.78807175208
# 3      152.928157498737  100.313796790298   1.9492333715404  300.221216434511
# 4      138.154297922142  96.9363796581796  1.90417361690823  310.570134060327
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# ...

# %%
df = df.apply(lambda x:x.replace('.0', '') if '.0' in x else x)

# %%
df.tail()
# Out:
#             Cycle_time Maximum_injection_pressure  Melt_temperature  \
# 9995  59.9129005628923            292.97890028194  205.515374969416
# 9996  61.9181016373862           307.680969444054  187.462084624218
# 9997  61.1433233449563           308.631036504834   204.48493019812
# 9998  58.7181401420203           318.363275133604  192.842720118924
# 9999  60.4832217945815           311.552942018297  182.572509500051
#
#      Mold_wall_temperature  Packing_pressure      Packing_time  \
# 9995      143.328945828417  100.829651078491  1.94598536760808
# 9996       152.22889802307  95.1407911700304   1.9800694919914
# 9997      160.338695831231  91.9377697417669  2.08939835987514
# 9998      151.049829395281  103.958171392048  1.90794258489936
# 9999      133.630735106449  106.891113788989  2.04269438743334
#
#            Part_weight  Quality  Sequence
# 9995   311.29351251448        1      9996
# 9996  317.116363995215        1      9997
# 9997  298.792023354371        1      9998
# ...

# %%
df.to_json('mockup.json', orient='records')

# %%
df.head()
# Out:
#    Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 0        60.0                       303.0             205.0
# 1        60.0                       316.0             191.0
# 2        59.0                       300.0             193.0
# 3        62.0                       295.0             212.0
# 4        59.0                       310.0             219.0
#
#    Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 0                  136.0              96.0           2.0        300.0
# 1                  144.0             103.0           2.0        284.0
# 2                  133.0             109.0           2.0        288.0
# 3                  153.0             100.0           2.0        300.0
# 4                  138.0              97.0           2.0        311.0
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# 3        1         4
# 4        1         5

# %%
nb_sequence = df.describe()['Sequence']['count']

# %%
nb_sequence
# Out:
# 10000.0

# %%
df.dtypes
# Out:
# Cycle_time                    object
# Maximum_injection_pressure    object
# Melt_temperature              object
# Mold_wall_temperature         object
# Packing_pressure              object
# Packing_time                  object
# Part_weight                   object
# Quality                        int64
# Sequence                       int64
# dtype: object

# %%
cols = df.select_dtypes(exclude=['float'] and ['int']).columns

# %%
df[cols] = df[cols].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
df.dtypes
# Out:
# Cycle_time                    float32
# Maximum_injection_pressure    float32
# Melt_temperature              float32
# Mold_wall_temperature         float32
# Packing_pressure              float32
# Packing_time                  float32
# Part_weight                   float32
# Quality                         int64
# Sequence                        int64
# dtype: object

# %%
df = df.round(2)

# %%
df.head()
# Out:
#    Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 0   60.240002                  303.179993        204.779999
# 1   59.709999                  316.450012        191.119995
# 2   59.450001                  300.429993        193.179993
# 3   61.650002                  294.809998        212.449997
# 4   59.250000                  310.500000        218.770004
#
#    Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 0             136.229996         96.220001          2.04   300.230011
# 1             144.110001        102.650002          1.93   283.559998
# 2             132.710007        108.589996          1.92   287.790009
# 3             152.929993        100.309998          1.95   300.220001
# 4             138.149994         96.940002          1.90   310.570007
#
#    Quality  Sequence
# 0        1         1
# 1        1         2
# 2        1         3
# 3        1         4
# 4        1         5

# %%
avg_cycle = df.describe()['Cycle_time']['mean']

# %%
avg_cycle
# Out:
# 60.0138053894043

# %%
df.describe()
# Out:
#          Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# count  10000.000000                10000.000000      10000.000000
# mean      60.013805                  299.959625        200.028839
# std        0.875639                    8.594129          8.653775
# min       58.000000                  280.000000        180.009995
# 25%       59.369999                  293.929993        193.949997
# 50%       60.020000                  299.970001        200.059998
# 75%       60.669998                  306.059998        206.320007
# max       61.990002                  319.989990        219.990005
#
#        Mold_wall_temperature  Packing_pressure  Packing_time   Part_weight  \
# count           10000.000000      10000.000000  10000.000000  10000.000000
# mean              149.890793        100.035370      2.000410    299.759399
# std                 8.486456          8.708156      0.057937      9.238999
# ...

# %%
data = df.loc[df['Quality'] == 0]

# %%
data.head()
# Out:
#      Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 30    59.169998                  300.559998        196.350006
# 410   61.430000                  297.500000        186.479996
# 494   60.610001                  289.480011        216.550003
# 547   60.740002                  307.459991        208.119995
# 554   61.689999                  292.299988        199.720001
#
#      Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 30              149.789993         95.809998          2.09   302.480011
# 410             138.009995         95.730003          2.09   299.420013
# 494             148.070007         97.360001          2.07   299.600006
# 547             146.059998        113.449997          1.92   290.609985
# 554             148.000000         86.400002          2.08   316.549988
#
#      Quality  Sequence
# 30         0        31
# 410        0       411
# 494        0       495
# 547        0       548
# 554        0       555

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 30 to 9704
# Data columns (total 9 columns):
# Cycle_time                    79 non-null float32
# Maximum_injection_pressure    79 non-null float32
# Melt_temperature              79 non-null float32
# Mold_wall_temperature         79 non-null float32
# Packing_pressure              79 non-null float32
# Packing_time                  79 non-null float32
# Part_weight                   79 non-null float32
# Quality                       79 non-null int64
# Sequence                      79 non-null int64
# dtypes: float32(7), int64(2)
# memory usage: 6.5 KB

# %%
data = data.round(0)

# %%
data = pd.read_json('/Users/user/Desktop/Flask_Blog/noQuality.json')

# %%
data.tail()
# Out:
#     Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 74          60                         300               219
# 75          60                         301               193
# 76          59                         298               185
# 77          60                         301               204
# 78          61                         294               219
#
#     Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 74                    158               114             2          303
# 75                    149                97             2          298
# 76                    142                83             2          300
# 77                    155               100             2          291
# 78                    153                99             2          303
#
#     Quality  Sequence
# 74        0      9021
# 75        0      9611
# 76        0      9644
# 77        0      9692
# 78        0      9705

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 9 columns):
# Cycle_time                    79 non-null int64
# Maximum_injection_pressure    79 non-null int64
# Melt_temperature              79 non-null int64
# Mold_wall_temperature         79 non-null int64
# Packing_pressure              79 non-null int64
# Packing_time                  79 non-null int64
# Part_weight                   79 non-null int64
# Quality                       79 non-null int64
# Sequence                      79 non-null int64
# dtypes: int64(9)
# memory usage: 5.6 KB

# %%
data.to_json('/Users/user/Desktop/Flask_Blog/noQuality.json', orient='records')

# %%
df = pd.read_json('/Users/user/Desktop/Flask_Blog/mockup.json')

# %%
dataGood = df.loc[df['Quality'] == 1]

# %%
dataGood = dataGood.sample(n=100)

# %%
dataGood.head()
# Out:
#       Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# 9790          60                         301               187
# 4142          59                         287               192
# 9200          59                         302               199
# 7160          61                         313               190
# 7363          60                         307               205
#
#       Mold_wall_temperature  Packing_pressure  Packing_time  Part_weight  \
# 9790                    151                88             2          292
# 4142                    164               101             2          303
# 9200                    146                93             2          310
# 7160                    154                96             2          314
# 7363                    154                86             2          310
#
#       Quality  Sequence
# 9790        1      9791
# 4142        1      4143
# 9200        1      9201
# 7160        1      7161
# ...

# %%
dataGood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 9790 to 7367
# Data columns (total 9 columns):
# Cycle_time                    100 non-null int64
# Maximum_injection_pressure    100 non-null int64
# Melt_temperature              100 non-null int64
# Mold_wall_temperature         100 non-null int64
# Packing_pressure              100 non-null int64
# Packing_time                  100 non-null int64
# Part_weight                   100 non-null int64
# Quality                       100 non-null int64
# Sequence                      100 non-null int64
# dtypes: int64(9)
# memory usage: 7.8 KB

# %%
dataGood.to_json('quality.json', orient='records')

# %%
df = pd.read_json('/Users/user/Desktop/Flask_Blog/noQuality.json')

# %%
def example(a, b, c, d, e ):
     if arg1 == 1 and arg2 == 2 and arg3 == 3:
          print("Example Text")

# %%
example(1,2,3)
# Out:
# Example Text

# %%
df['Cycle_time'].value_counts()
# Out:
# 60    33
# 61    25
# 59    16
# 58     3
# 62     2
# Name: Cycle_time, dtype: int64

# %%
ranges = [0,58,61,62]

# %%
df.groupby(pd.cut(df.Cycle_time, ranges)).count()
# Out:
#             Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# Cycle_time
# (0, 58]              3                           3                 3
# (58, 61]            74                          74                74
# (61, 62]             2                           2                 2
#
#             Mold_wall_temperature  Packing_pressure  Packing_time  \
# Cycle_time
# (0, 58]                         3                 3             3
# (58, 61]                       74                74            74
# (61, 62]                        2                 2             2
#
#             Part_weight  Quality  Sequence
# Cycle_time
# (0, 58]               3        3         3
# (58, 61]             74       74        74
# (61, 62]              2        2         2

# %%
cycle = 74/79 #accept 58-61

# %%
print(cycle)
# Out:
# 0.9367088607594937

# %%
ranges = [0,280,290,300,310,320]

# %%
df.groupby(pd.cut(df.Maximum_injection_pressure, ranges)).count()
# Out:
#                             Cycle_time  Maximum_injection_pressure  \
# Maximum_injection_pressure
# (0, 280]                             1                           1
# (280, 290]                          14                          14
# (290, 300]                          30                          30
# (300, 310]                          24                          24
# (310, 320]                          10                          10
#
#                             Melt_temperature  Mold_wall_temperature  \
# Maximum_injection_pressure
# (0, 280]                                   1                      1
# (280, 290]                                14                     14
# (290, 300]                                30                     30
# (300, 310]                                24                     24
# (310, 320]                                10                     10
#
#                             Packing_pressure  Packing_time  Part_weight  \
# ...

# %%
inject = (14+30+24)/df.Maximum_injection_pressure.size

# %%
print(inject) #accept 280-310
# Out:
# 0.8607594936708861

# %%
ranges = [0,180,190,200,210,220,230]

# %%
df.groupby(pd.cut(df.Melt_temperature, ranges)).count()
# Out:
#                   Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# Melt_temperature
# (0, 180]                   0                           0                 0
# (180, 190]                12                          12                12
# (190, 200]                27                          27                27
# (200, 210]                27                          27                27
# (210, 220]                13                          13                13
# (220, 230]                 0                           0                 0
#
#                   Mold_wall_temperature  Packing_pressure  Packing_time  \
# Melt_temperature
# (0, 180]                              0                 0             0
# (180, 190]                           12                12            12
# (190, 200]                           27                27            27
# (200, 210]                           27                27            27
# ...

# %%
melt = (27+27+13)/df.Melt_temperature.size # accept 190 - 220
print(melt)
# Out:
# 0.8481012658227848

# %%
#df['Mold_wall_temperature'].value_counts()

# %%
df[(df['Mold_wall_temperature'] >= 160)].count()
# Out:
# Cycle_time                    12
# Maximum_injection_pressure    12
# Melt_temperature              12
# Mold_wall_temperature         12
# Packing_pressure              12
# Packing_time                  12
# Part_weight                   12
# Quality                       12
# Sequence                      12
# dtype: int64

# %%
mold = (79-12)/79 #accept 130-160
print(melt)
# Out:
# 0.8481012658227848

# %%
weight_groups = pd.cut(df['Part_weight'], bins=[0,280,290,300,310,320])

# %%
ranges =[0,280,290,300,310,320]
df.groupby(pd.cut(df.Part_weight, ranges)).count()
# Out:
#              Cycle_time  Maximum_injection_pressure  Melt_temperature  \
# Part_weight
# (0, 280]              0                           0                 0
# (280, 290]           13                          13                13
# (290, 300]           30                          30                30
# (300, 310]           27                          27                27
# (310, 320]            9                           9                 9
#
#              Mold_wall_temperature  Packing_pressure  Packing_time  \
# Part_weight
# (0, 280]                         0                 0             0
# (280, 290]                      13                13            13
# (290, 300]                      30                30            30
# (300, 310]                      27                27            27
# (310, 320]                       9                 9             9
#
#              Part_weight  Quality  Sequence
# Part_weight
# (0, 280]               0        0         0
# ...

# %%
weight = (79-9)/79 #accept 280-310
print(weight)
# Out:
# 0.8860759493670886

# %%
def count_values_in_range(series, range_min, range_max):

    # "between" returns a boolean Series equivalent to left <= series <= right.
    # NA values will be treated as False.
    return series.between(left=range_min, right=range_max).sum()
pack_pressure = (df.Packing_pressure.between(80,110).sum())/df.Packing_pressure.size
print(pack_pressure) #accept 80-110
# Out:
# 0.8987341772151899

# %%
df.groupby(["Cycle_time", "Packing_time"]).size()
# Out:
# Cycle_time  Packing_time
# 58          2                3
# 59          2               16
# 60          2               33
# 61          2               25
# 62          2                2
# dtype: int64

# %%
df = df.groupby(["Maximum_injection_pressure", "Packing_pressure"])

# %%
df["Quality"][(df["Maximum_injection_pressure"] > 310) & (df["Packing_pressure"] > 110)].count()
# Out:
# 1
